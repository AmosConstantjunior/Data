# %%
import pandas
import numpy as np
from sqlalchemy import create_engine
import pandas as pd

# %%
Netflix_title = pandas.read_csv('netflix_titles.csv', encoding='latin-1')
Netflix_show = pandas.read_csv('Netflix_Shows.csv', encoding='latin-1')
Netflix_title
# Out:
#        show_id     type                                              title  \
# 0     81145628    Movie            Norm of the North: King Sized Adventure
# 1     80117401    Movie                         Jandino: Whatever it Takes
# 2     70234439  TV Show                                 Transformers Prime
# 3     80058654  TV Show                   Transformers: Robots in Disguise
# 4     80125979    Movie                                       #realityhigh
# 5     80163890  TV Show                                            Apaches
# 6     70304989    Movie                                           Automata
# 7     80164077    Movie                 Fabrizio Copano: Solo pienso en mi
# 8     80117902  TV Show                                       Fire Chasers
# 9     70304990    Movie                                        Good People
# 10    80169755    Movie                      JoaquÃ­n Reyes: Una y no mÃ¡s
# ...

# %%
Netflix_show
# Out:
#                                           title rating  \
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
len('Netflix_title[title]')
# Out:
# 20

# %%
len('Netflix_title[director]')
# Out:
# 23

# %%
maxlen = 0
for title in Netflix_title['duration']:
        if len(str(title)) > maxlen:
            maxlen = len(str(title))
print(maxlen)

# show_id = 8
# title=104
# director = 208
# cast = 771
# country : 123
# date_added =19
# release_year = 4
# duration =10
# rating = 8
# listed_in = 79
# description )250
# Out:
# 10

# %%
maxlen = 0
for title in Netflix_show['user rating size']:
        if len(str(title)) > maxlen:
            maxlen = len(str(title))
print(maxlen)
# title = 63
# rating = 8
# ratingLevel = 125
# ratingDescription = 3
# user rating score = 4
# user rating size : 2

# CREATE TABLE Netflix_shows (
#     id INT NOT NULL AUTO_INCREMENT,
#     title VARCHAR(64),
#     rating VARCHAR(9),
#     ratingLevel VARCHAR(126),
#     ratingDescription INT NOT NULL,
#     release_year INT NOT NULL,
#     user_rating_score VARCHAR(4),
#     user_rating_size INT NOT NULL,
#     PRIMARY KEY(id)
# );

# CREATE TABLE Netflix_show (
#     title VARCHAR(255) NOT NULL,
#     rating VARCHAR(9) NOT NULL,
#     ratingLevel VARCHAR(126),
#     ratingDescription INT NOT NULL,
#     release_year INT NOT NULL,
#     user_rating_score float NULL,
#     user_rating_size INT NOT NULL,
#     id INT NOT NULL AUTO_INCREMENT,
#     PRIMARY KEY(id)
# );
# Out:
#   File "<ipython-input-7-bff0927cbabd>", line 14
#     CREATE TABLE discounts (
#                ^
# SyntaxError: invalid syntax

# %%
# expired_date DATE NOT NULL,
#     amount DECIMAL(10 , 2 ) NULL,
#     PRIMARY KEY (id)
    
# LOAD DATA INFILE '/Documents/Brief_bd_/Netflix_Shows.csv' 
# INTO TABLE Netflix_show 
# FIELDS TERMINATED BY ',' 
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 ROWS;
    
#     /Documents/Brief_bd_

# %%
# CREATE TABLE Netflix_show (     id INT NOT NULL AUTO_INCREMENT,     title VARCHAR(255) NOT NULL,     rating VARCHAR(9) NOT NULL,     ratingLevel VARCHAR(126),     ratingDescription INT NOT NULL,     release_year INT NOT NULL,     user_rating_score float NULL,     user_rating_size INT NOT NULL, PRIMARY KEY (id) )

# %%
# ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY 'admin';

# USE Netflix
# LOAD DATA LOCAL INFILE '/Documents/Brief_bd_/Netflix_Shows.csv' 
# INTO TABLE Netflix_show;


# CREATE TABLE netflix_titles( 
#   show_id INT NOT NULL,
#   type VARCHAR(10),
#   title VARCHAR(110),
#   director VARCHAR(210),
#   cast VARCHAR(780),
#   country VARCHAR(130),
#   date_added VARCHAR(20),
#   release_year INT NOT NULL,
#   rating VARCHAR(10),
#   duration VARCHAR(10),
#   listed_in VARCHAR(80),
#   description VARCHAR(280),
#   PRIMARY KEY(show_id)
#   );

# LOAD DATA LOCAL INFILE '/home/constantjunior/Documents/Brief_bd_/Netflix_Shows.csv' INTO TABLE Netflix.Netflix_show FIELDS TERMINATED BY ',' ENCLOSED BY '"' IGNORE 1 ROWS;

# %%
# LOAD DATA LOCAL INFILE 'Netflix_Shows.csv' 
# INTO TABLE Netflix_show
# CHARACTER SET latin1
# FIELDS TERMINATED BY ',' 
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 ROWS;(title, rating, ratingLevel, ratingDescription,release_year, user_rating_score, user_rating_size);
#  LOAD DATA LOCAL INFILE 'Netflix\ Shows.csv' 
# INTO TABLE netflix_shows
# CHARACTER SET latin1
# FIELDS TERMINATED BY ',' 
# ENCLOSED BY '"'
# LINES TERMINATED BY '\r'
# IGNORE 1 LINES(title, rating, ratingLevel, ratingDescription,release year, user rating score, user rating size);

# %%
# LOAD DATA LOCAL INFILE 'netflix_titles.csv' 
# INTO TABLE netflix_titles
# CHARACTER SET latin1
# FIELDS TERMINATED BY ',' 
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 ROWS;

# %%
engine = create_engine('mysql+pymysql://root:admin@localhost/Netflix')
dbConnection=engine.connect()
# car_data.to_sql('car',dbConnection, if_exists='append',index=False)


frame = pd.read_sql("select * from Netflix.Netflix_show", dbConnection);
frame
# Out:
#                                           title rating  \
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
frame2 = pd.read_sql("select * from Netflix.netflix_titles", dbConnection);
frame2
# Out:
#        show_id     type                                   title  \
# 0            0     None                                    None
# 1       247747    Movie                      Amar Akbar Anthony
# 2       269880    Movie                                Bad Boys
# 3       281550    Movie                                La Bamba
# 4       296682    Movie                                   Benji
# 5       347365    Movie                                Candyman
# 6       352989    Movie                                  Carrie
# 7       374651    Movie                 Chitty Chitty Bang Bang
# 8       449931    Movie                          Doctor Zhivago
# 9       484369    Movie                           The Evil Dead
# 10      485218    Movie                      Executive Decision
# 11      506464    Movie                    The First Wives Club
# 12      510854    Movie                         The Flintstones
# 13      520489    Movie             Four Weddings and a Funeral
# ...

# %%
# 6. Afficher tous les titres de films de la table netflix_titles dont l’ID est inférieur strict à 80000000 

reponse6 =pd.read_sql("SELECT * FROM Netflix.netflix_titles WHERE show_id < 80000000 ", dbConnection); 
reponse6
# Out:
#       show_id     type                                             title  \
# 0           0     None                                              None
# 1      247747    Movie                                Amar Akbar Anthony
# 2      269880    Movie                                          Bad Boys
# 3      281550    Movie                                          La Bamba
# 4      296682    Movie                                             Benji
# 5      347365    Movie                                          Candyman
# 6      352989    Movie                                            Carrie
# 7      374651    Movie                           Chitty Chitty Bang Bang
# 8      449931    Movie                                    Doctor Zhivago
# 9      484369    Movie                                     The Evil Dead
# 10     485218    Movie                                Executive Decision
# 11     506464    Movie                              The First Wives Club
# ...

# %%
# 7. Afficher toutes les durée des TV Show (colonne duration)

Tv_show_duration = pd.read_sql("select duration from netflix_titles where netflix_titles.type = 'TV Show'", dbConnection)
Tv_show_duration
# Out:
#         duration
# 0      4 Seasons
# 1      6 Seasons
# 2      8 Seasons
# 3      3 Seasons
# 4      4 Seasons
# 5      5 Seasons
# 6      7 Seasons
# 7      5 Seasons
# 8     15 Seasons
# 9      2 Seasons
# 10     6 Seasons
# 11    14 Seasons
# 12      1 Season
# 13     5 Seasons
# 14     7 Seasons
# 15     6 Seasons
# 16      1 Season
# 17    11 Seasons
# 18    10 Seasons
# 19     7 Seasons
# 20     8 Seasons
# 21     7 Seasons
# 22     3 Seasons
# 23     4 Seasons
# 24     6 Seasons
# 25      1 Season
# 26     7 Seasons
# 27     7 Seasons
# 28    11 Seasons
# 29     2 Seasons
# ...          ...
# 1085    1 Season
# 1086    1 Season
# 1087    1 Season
# 1088    1 Season
# 1089    1 Season
# 1090    1 Season
# 1091    1 Season
# 1092    1 Season
# 1093    1 Season
# 1094    1 Season
# 1095    1 Season
# 1096    1 Season
# 1097    1 Season
# 1098    1 Season
# 1099    1 Season
# 1100    1 Season
# 1101    1 Season
# 1102    1 Season
# 1103    1 Season
# 1104    1 Season
# ...

# %%
# 8. Réaliser une veille sur ces notions MySQL 


# 1

# %%
# 9. Afficher tous les noms de films communs aux 2 tables (netflix_titles et netflix_shows)

# %%
TvShow =  pd.read_sql("SELECT DISTINCT Netflix_show.title FROM Netflix_show, netflix_titles WHERE Netflix_show.title = netflix_titles.title" , dbConnection)
TvShow
# Out:
#                                                  title
# 0                                               Tarzan
# 1                                               Grease
# 2                                     An American Tail
# 3                                                 Blow
# 4                                                Balto
# 5                                Spy Kids 3: Game Over
# 6    An American Tail: The Mystery of the Night Mon...
# 7                         Teenage Mutant Ninja Turtles
# 8                                            Bee Movie
# 9                                             Coraline
# 10                                          The L Word
# 11                                              Dexter
# 12                                               Skins
# 13                                                NCIS
# 14                                           Limitless
# 15                                         Gossip Girl
# ...

# %%
# 10. Calculer la durée totale de tous les films (Movie)S de votre table netflix_titles

# %%
# 11. Compter le nombre de TV Shows de votre table ‘netflix_shows’ dont le ‘ratingLevel’ est renseigné. 
 
NombreTvShow=  pd.read_sql('SELECT  Count(*) FROM Netflix.Netflix_show WHERE Netflix.Netflix_show.ratingLevel  != ""', dbConnection)
NombreTvShow
# Out:
#    Count(*)
# 0       941

# %%
# 12. Compter les films et TV Shows pour lesquels les noms (title) sont les mêmes sur les 2 tables et dont le ‘release year’ est supérieur à 2016.

ComptNomb = pd.read_sql("SELECT COUNT(DISTINCT Netflix_show.title) FROM Netflix_show, netflix_titles WHERE Netflix_show.title = netflix_titles.title AND netflix_titles.release_year > 2016 AND Netflix_show.release_year > 2016" , dbConnection)
ComptNomb

# relas = pd.read_sql("SELECT COUNT(DISTINCT Netflix_show.title) FROM Netflix_show INNER JOIN netflix_titles ON Netflix_show.title = netflix_titles.title WHERE Netflix_show.release_year > 2016 AND netflix_titles.release_year > 2016  GROUP BY Netflix_show.title ORDER BY Netflix_show.title; " , dbConnection)
# relas
# SELECT COUNT (Netflix_show.title) FROM Netflix_show, netflix_titles WHERE Netflix_show.title = netflix_titles.title
# Out:
#    COUNT(DISTINCT Netflix_show.title)
# 0                                  17

# %%
# 13. Supprimer la colonne ‘rating’ de votre table ‘netflix_shows’ 

supRating= pd.read_sql("ALTER TABLE Netflix_show DROP COLUMN rating", dbConnection)

# %%
tableText = pd.read_sql("select * from Netflix.Netflix_show", dbConnection)
tableText
# Out:
#                                           title  \
# 0                                  White Chicks
# 1                           Lucky Number Slevin
# 2                                Grey's Anatomy
# 3                                  Prison Break
# 4                         How I Met Your Mother
# 5                                  Supernatural
# 6                                  Breaking Bad
# 7                           The Vampire Diaries
# 8                              The Walking Dead
# 9                           Pretty Little Liars
# 10                             Once Upon a Time
# 11                                     Sherlock
# 12                                   Death Note
# 13                                       Naruto
# 14                                   The Hunter
# 15                        Lottie Dottie Chicken
# 16                                        Arrow
# 17                                 Black Mirror
# ...

# %%
# 14. Supprimer les 100 dernières lignes de la table ‘netflix_shows’ 

lig100= pd.read_sql("select * from Netflix_show order by id desc limit 100", dbConnection);
lig100
# Out:
#                                                 title  \
# 0                                     Growing Up Wild
# 1                                         Beary Tales
# 2                                    Precious Puppies
# 3                             The Secret Life of Pets
# 4                                             The BFG
# 5                                            Pup Star
# 6                           Wiener Dog Internationals
# 7                          Alpha and Omega: Dino Digs
# 8                                  Dawn of the Croods
# 9                                   My Animal Friends
# 10                                    Russell Madness
# 11                                         Paddington
# 12                                         Mia and Me
# 13                            PokÌ©mon: Indigo League
# 14                                          Step Dogs
# 15                               The Magic School Bus
# ...

# %%
# Sup100 = pd.read_sql('DELETE FROM Netflix_show order by id desc limit 100', dbConnection);

# %%
# 15. Le champs “ratingLevel” pour le TV show “Marvel's Iron Fist” de la table ‘netflix_shows’ est vide, pouvez-vous ajouter un commentaire ? 
marvelIro = pd.read_sql("select * from Netflix_show where title='Marvel\\'s Iron Fist'", dbConnection)
marvelIro
# Out:
#                 title          ratingLevel  ratingDescription  release_year  \
# 0  Marvel's Iron Fist  Test de commentaire                110          2017
# 1  Marvel's Iron Fist  Test de commentaire                110          2017
# 2  Marvel's Iron Fist  Test de commentaire                110          2017
# 3  Marvel's Iron Fist  Test de commentaire                110          2017
#
#    user_rating_score  user_rating_size   id
# 0               98.0                80   26
# 1               98.0                80   78
# 2               98.0                80  119
# 3               98.0                80  434

# %%
pd.read_sql("UPDATE Netflix_show SET ratingLevel  = 'Test de commentaire' WHERE id=26;", dbConnection);

# UPDATE table
# SET nom_colonne_1 = 'nouvelle valeur'
# WHERE condition
